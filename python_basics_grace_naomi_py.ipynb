# %% [markdown]
# <a href="https://colab.research.google.com/github/gracenaomi1122/my-first-repo/blob/main/python_basics_grace_naomi_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task1-Printing all values in a single statement using variables and data types
name = "N Grace Naomi" #string
age = 21                #integer
height = 1.54           #float
is_student = True       #boolean
print(name, age, height, is_student)
# Out:
# N Grace Naomi 21 1.54 True

# %%
#Task2 -String Formatting
#Verifying using the variables from task1

print(f"Name:{name} |Age:{age}| Height:{height}| Student:{is_student}")
# Out:
# Name:N Grace Naomi |Age:21| Height:1.54| Student:True

# %%
#Task3 : Arithmetic Operations
#Verifying using the age variable,calculate and print
age_in_months = age*12
age_in_days = age*365
remainder = age%7
age_squared=age**2
print("Age in months:",age_in_months)
print("Age in days:",age_in_days)
print("Remainder when age is divided by 7:", remainder)
print("Age squared:",age_squared)
# Out:
# Age in months: 252
# Age in days: 7665
# Remainder when age is divided by 7: 0
# Age squared: 441
