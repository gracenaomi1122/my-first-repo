# %% [markdown]
# <a href="https://colab.research.google.com/github/gracenaomi1122/my-first-repo/blob/main/Python_Organizing_with_Functions%3B_Python_Data_Collections_Subjective_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task1
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Task2
#Print only odd numbers between 1 and 10:

for i in range(1, 11, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#Task3
#Nested loop to print the pattern:


#0 0,0 1,1 0,1 1,2 0,2 1

for i in range(3):
    for j in range(2):
        print(i, j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
#Task 4
#Print numbers from 1 to 7, but stop when the number is 5:


for i in range(1, 8):
    if i == 5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4
