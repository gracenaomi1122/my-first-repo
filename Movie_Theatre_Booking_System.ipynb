# %% [markdown]
# <a href="https://colab.research.google.com/github/gracenaomi1122/my-first-repo/blob/main/Movie_Theatre_Booking_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Movie Theatre Booking System
TOTAL_SEATS = 350
remaining_seats = TOTAL_SEATS

total_bookings = 0
tickets_sold = 0
rejected_bookings = 0

while True:
    tickets = int(input("Enter number of tickets (0 to exit): "))

    # Exit condition
    if tickets == 0:
        break

    # Validate ticket range
    if tickets < 1 or tickets > 15:
        print("Invalid number of tickets (1-15 only)")
        continue

    # Check seat availability
    if tickets > remaining_seats:
        print("BOOKING REJECTED - Not enough seats")
        rejected_bookings += 1
        continue

    # Input ages
    valid = True
    for i in range(tickets):
        age = int(input(f"Enter age of person {i+1}: "))
        if age < 12:
            valid = False

    # Check age restriction
    if not valid:
        print("BOOKING REJECTED - Age restriction")
        rejected_bookings += 1
        continue

    # Confirm booking
    print(f"BOOKING CONFIRMED - {tickets} tickets")
    total_bookings += 1
    tickets_sold += tickets
    remaining_seats -= tickets

    # Stop if full
    if remaining_seats == 0:
        break

# Final report
print("\nFinal Report:")
print("Total Bookings:", total_bookings)
print("Total Tickets Sold:", tickets_sold)
print("Rejected Bookings:", rejected_bookings)
print("Remaining Seats:", remaining_seats)
# Out:
# Enter number of tickets (0 to exit): 5
# Enter age of person 1: 45
# Enter age of person 2: 12
# Enter age of person 3: 12
# Enter age of person 4: 11
# Enter age of person 5: 34
# BOOKING REJECTED - Age restriction
# Enter number of tickets (0 to exit): 3
# Enter age of person 1: 20
# Enter age of person 2: 18
# Enter age of person 3: 16
# BOOKING CONFIRMED - 3 tickets
# Enter number of tickets (0 to exit): 5
# Enter age of person 1: 15
# Enter age of person 2: 14
# Enter age of person 3: 13
# Enter age of person 4: 12
# Enter age of person 5: 11
# BOOKING REJECTED - Age restriction
# Enter number of tickets (0 to exit): 0
#
# Final Report:
# Total Bookings: 1
# Total Tickets Sold: 3
# Rejected Bookings: 2
# Remaining Seats: 347
